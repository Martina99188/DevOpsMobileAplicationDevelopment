# %%
# Import library and modules
import pandas as pd
from pathlib import Path
import math
import matplotlib as plt
import numpy as np

# %%
# Read a .csv file 'AnalisiFinale.csv'
df = pd.read_csv('./sample_data/SampleCommits.csv', sep=',')
df
# Out:
#                                                 COMMIT: CATEGORIES:  \
# 0                                                   NaN         NaN
# 1     build-system: don't always build qtserialbluet...       BUILD
# 2     Update dependency versions\n \n Fix test build...       BUILD
# 3     Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4     Translated using Weblate (Italian)\n \n Curren...       BUILD
# ...                                                 ...         ...
# 1995  Let git clones without a google-service to bui...    NO LABEL
# 1996  MMS support , https://github.com/jberkel/sms-b...    NO LABEL
# 1997  Disabled --debug for travis , https://github.c...    NO LABEL
# 1998  类重命名 , https://github.com/TakWolf/CNode-Materi...    NO LABEL
# 1999  Using stripe charges instead of customers to r...    NO LABEL
#
#      KEYWORDS DA UNA PAROLA KEYWORDS DA MAX 2 PAROLE KEYWORDS DA MAX 3 PAROLE  \
# ...

# %%
# Delete firsts columns
df.drop(['KEYWORDS DA UNA PAROLA', 'KEYWORDS DA MAX 2 PAROLE', 'KEYWORDS DA MAX 3 PAROLE', 'KEYWORDS GENERALI'], axis=1, inplace=True)

# %%
df
# Out:
#                                                 COMMIT: CATEGORIES:  \
# 0                                                   NaN         NaN
# 1     build-system: don't always build qtserialbluet...       BUILD
# 2     Update dependency versions\n \n Fix test build...       BUILD
# 3     Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4     Translated using Weblate (Italian)\n \n Curren...       BUILD
# ...                                                 ...         ...
# 1995  Let git clones without a google-service to bui...    NO LABEL
# 1996  MMS support , https://github.com/jberkel/sms-b...    NO LABEL
# 1997  Disabled --debug for travis , https://github.c...    NO LABEL
# 1998  类重命名 , https://github.com/TakWolf/CNode-Materi...    NO LABEL
# 1999  Using stripe charges instead of customers to r...    NO LABEL
#
#       Unnamed: 6 KEYWORDS DA UNA PAROLA SENZA RIPETIZIONI   FASI Unnamed: 9  \
# ...

# %%
# Delete remaining columns
df.drop(['Unnamed: 6', 'KEYWORDS DA UNA PAROLA SENZA RIPETIZIONI', 'FASI', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'], axis=1, inplace=True)

# %%
df
# Out:
#                                                 COMMIT: CATEGORIES:
# 0                                                   NaN         NaN
# 1     build-system: don't always build qtserialbluet...       BUILD
# 2     Update dependency versions\n \n Fix test build...       BUILD
# 3     Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4     Translated using Weblate (Italian)\n \n Curren...       BUILD
# ...                                                 ...         ...
# 1995  Let git clones without a google-service to bui...    NO LABEL
# 1996  MMS support , https://github.com/jberkel/sms-b...    NO LABEL
# 1997  Disabled --debug for travis , https://github.c...    NO LABEL
# 1998  类重命名 , https://github.com/TakWolf/CNode-Materi...    NO LABEL
# 1999  Using stripe charges instead of customers to r...    NO LABEL
#
# [2000 rows x 2 columns]

# %%
# Checking if there are NaN values.
df.isnull().any()
# Out:
# COMMIT:        True
# CATEGORIES:    True
# dtype: bool

# %%
# Check the NaN values in the column 'COMMIT:'
df[df['COMMIT:'].isnull()]
# Out:
#   COMMIT: CATEGORIES:
# 0     NaN         NaN

# %%
# Check the NaN values in the column 'CATEGORIES:'
df[df['CATEGORIES:'].isnull()]
# Out:
#   COMMIT: CATEGORIES:
# 0     NaN         NaN

# %%
# Delete NaN values
df.dropna(inplace=True)

# %%
# Check if the NaN values are deleted
df.isnull().any()
# Out:
# COMMIT:        False
# CATEGORIES:    False
# dtype: bool

# %%
df
# Out:
#                                                 COMMIT: CATEGORIES:
# 1     build-system: don't always build qtserialbluet...       BUILD
# 2     Update dependency versions\n \n Fix test build...       BUILD
# 3     Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4     Translated using Weblate (Italian)\n \n Curren...       BUILD
# 5     Merge branch 'master' of https://Bananeweizen@...       BUILD
# ...                                                 ...         ...
# 1995  Let git clones without a google-service to bui...    NO LABEL
# 1996  MMS support , https://github.com/jberkel/sms-b...    NO LABEL
# 1997  Disabled --debug for travis , https://github.c...    NO LABEL
# 1998  类重命名 , https://github.com/TakWolf/CNode-Materi...    NO LABEL
# 1999  Using stripe charges instead of customers to r...    NO LABEL
#
# [1999 rows x 2 columns]

# %%
# View the first 100 rows
df[0:100]
# Out:
#                                                COMMIT: CATEGORIES:
# 1    build-system: don't always build qtserialbluet...       BUILD
# 2    Update dependency versions\n \n Fix test build...       BUILD
# 3    Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4    Translated using Weblate (Italian)\n \n Curren...       BUILD
# 5    Merge branch 'master' of https://Bananeweizen@...       BUILD
# ..                                                 ...         ...
# 96   Merge pull request #107 from KrodukCZ/patch-1\...          CI
# 97   Merge remote-tracking branch 'refs/remotes/pro...          CI
# 98   Merge branch 'feature' , https://github.com/VR...          CI
# 99   Merge pull request #1501 from nailyk-weblate/w...          CI
# 100  Merge pull request #657\n \n Add support for G...          CI
#
# [100 rows x 2 columns]

# %%
# Delete the 'NO LABEL' categories
df = df[df["CATEGORIES:"].str.contains("NO LABEL") == False]

# %%
# Dataframe with the 'NO LABEL' categories
df
# Out:
#                                                 COMMIT: CATEGORIES:
# 1     build-system: don't always build qtserialbluet...       BUILD
# 2     Update dependency versions\n \n Fix test build...       BUILD
# 3     Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4     Translated using Weblate (Italian)\n \n Curren...       BUILD
# 5     Merge branch 'master' of https://Bananeweizen@...       BUILD
# ...                                                 ...         ...
# 1819  test(server:sequence): fixed SequenceServiceSp...        TEST
# 1820  [test suite] added Rijndael/HMAC compatibility...        TEST
# 1821  Pass BaseVehicleDataSink tests. , https://gith...        TEST
# 1822  autotools: support running the Android tests f...        TEST
# 1823  app: update GpgIdentifier tests\n \n Signed-of...       TEST
#
# [1753 rows x 2 columns]

# %%
df['COMMIT:'].replace(",", "")
# Out:
#                                                 COMMIT: CATEGORIES:
# 1     build-system: don't always build qtserialbluet...       BUILD
# 2     Update dependency versions\n \n Fix test build...       BUILD
# 3     Downgrade gradle to 2.2.1 , https://github.com...       BUILD
# 4     Translated using Weblate (Italian)\n \n Curren...       BUILD
# 5     Merge branch 'master' of https://Bananeweizen@...       BUILD
# ...                                                 ...         ...
# 1819  test(server:sequence): fixed SequenceServiceSp...        TEST
# 1820  [test suite] added Rijndael/HMAC compatibility...        TEST
# 1821  Pass BaseVehicleDataSink tests. , https://gith...        TEST
# 1822  autotools: support running the Android tests f...        TEST
# 1823  app: update GpgIdentifier tests\n \n Signed-of...       TEST
#
# [1753 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
# ...

# %%
# Saving the cleaned dataframe, so we can easly use it.
filepath = Path('./sample_data/DataframeCleaned.csv')
filepath.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(filepath, sep=',')
